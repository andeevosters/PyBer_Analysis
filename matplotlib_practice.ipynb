# %% [markdown]
# # 5.1.3 Create Line Charts

# %% [markdown]
# ## Create a Line Chart Using the MATLAB Method

# %%
# To display plots directly below the code cell that produced it
# %matplotlib inline

# When you run a cell that starts with %, "magic" happens behind the scenes and sets the back-end processor used for charts. Using it with the inline value displays the chart within the cell for a Jupyter Notebook file.

# %%
# Import dependencies (matplotlib) and module (pyplot).
import matplotlib.pyplot as plt

# The pyplot module will allow us to create all the necessary charts; create a plotting area in a figure; plot lines in a plotting area; and annotate the chart with labels, colors, and other decorative features.

# %%
# Add data in the form of arrays/lists...

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# The purpose of plt.plot() is to create the figure with the current axes, x and y.

# %% [markdown]
# ## Create a Line Chart Using the Object-Oriented Interface

# %%
# Create the plot with ax.plt()...

# To create a figure, use fig, ax = plt.subplots().
fig, ax = plt.subplots()

# To define the axes, use ax.plot() and divide the axes by a comma.
ax.plot(x_axis, y_axis)

# %% [markdown]
# Let's break down what the code is doing:
#
# 1. The plt.subplots() function returns a tuple that contains a figure and axes object(s).
# 2. fig, ax = plt.subplots() unpacks the tuple into the variables fig and ax.
# 3. The first variable, fig, references the figure.
# 4. The second variable, ax, references the axes of the figure and allows us to annotate the figure.
# 5. The ax.plot(x_axis, y_axis) plots the data from the x and y axes.
#
# The fig, ax = plt.subplots() line of code can also be written like this.
#
# fig = plt.figure()
#
# ax = fig.add_subplot()

# %% [markdown]
# #### Another way

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %% [markdown]
# #### Another way?

# %% [markdown]
# To change figure-level attributes (such as axis labels, a title, or a legend) or save the figure as an image, use fig = plt.figure().

# %% [markdown]
# # Use plt.show()

# %% [markdown]
# If you search for examples of Matplotlib graphs on the internet, you'll typically find examples that have plt.show() at the end of the graphing script.
#
# The plt.show() function looks for all the active figure objects and opens a window that displays them if you have two or more sets of data to plot.

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %% [markdown]
# ### IMPORTANT

# %% [markdown]
# plt.show() should only be used once per session because it can cause the graph to display improperly. If you have problems with data not being displayed properly, you may have to restart your kernel and clear your output.

# %% [markdown]
# # 5.1.4 ANNOTATE CHARTS

# %% [markdown]
# With Matplotlib, we can add labels to the axes, a title, and a legend. We can also change the thickness of the graphed line and add markers for the data points.

# %% [markdown]
# ## Annotate Charts Using the MATLAB Method

# %% [markdown]
# ### Matplotlib Functions

# %% [markdown]
# 1. plt.figure(figsize=(w, h))	Change the size of the figure in pixels. Added on the first line of the script.
# 2. plt.plot(x, y, label='line')	Add a label that will be added to the legend.
# 3. plt.xlim(min, max)	Set the min and max range of the x-axis.
# 4. plt.ylim(min, max)	Set the min and max range of the y-axis.
# 5. plt.xlabel('x label')	Add a label to the x-axis.
# 6. plt.ylabel('y label')	Add a label to the y-axis.
# 7. plt.title("Title")	Add a title.
# 8. plt.legend()	Add a legend.
# 9. plt.grid()	Add a grid to the chart.
# 10. plt.savefig("add a path and figure extension")	Save the figure with the given extension. Added at the end of the script.

# %% [markdown]
# ### Adding Labels

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# %% [markdown]
# ### Formatting

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by Month")

# Add a grid.
plt.grid()

# Add the legend.
plt.legend()

# Change size.
plt.figure(figsize=(20, 10))
# plt.subplots(figsize=(20, 10)) works too.

# %% [markdown]
# plt.xlim(0, 5) and plt.xlim("Jan", "June") will both show the months from Januray through June.

# %% [markdown]
# ## Annotate Charts Using the Object-Oriented Interface

# %% [markdown]
# ### Matplotlib Object-Oriented Functions

# %% [markdown]
# 1. fig, ax = plt.subplots(figsize=(w, h))	Change the size of the figure in pixels. Add this in the subplots() function.
# 2. ax.plot(x, y, label='line')	Add a label that will be added to the legend.
# 3. ax.set_ylim(min, max)	Sets the min and max range of the y-axis.
# 4. ax.set_xlim(min, max)	Sets the min and max range of the x-axis.
# 5. ax.set_xlabel('x label')	Add a label to the x-axis.
# 6. ax.set_ylabel('y label')	Add a label to the y-axis.
# 7. ax.set_title("Title")	Add a title.
# 8. ax.legend()	Add a legend.
# 9. ax.grid()	Add a grid to the chart.

# %% [markdown]
# ### SKILL DRILL

# %%
# Create the plot with ax.plt()
x = x_axis
y = y_axis
ax = plt.axes()
ax.plot(x_axis, y_axis)

# Change the line color to green, the marker to a diamond, and the line width to 2 points.
ax.plot(x, y, label='Boston', color="green", marker="D", linewidth=2)

# Add a legend for the city of Boston.
ax.legend()

# Add a title and axes labels.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
ax.set_title("PyBer Fare by Month")

# Add a y-axis limit.
ax.set_ylim(0, 45)

# Add grid lines.
ax.grid()

# %% [markdown]
# # 5.1.5 Create Bar Charts Using the MATLAB Approach

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# ## MATLAB Graph Types

# %% [markdown]
# plt.plot = line chart
#
# plt.bar = vertical bar chart
#
# plt.barh = horizontal bar chart
#
# plt.gca().invert_yaxis() = invert the order of the y axis (handy when showing most recent month to month logest ago)

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# If you want the data on opposite axes, switch the arguments in the barh() function and run the cell again:

# %%
# Create the plot
plt.barh(y_axis, x_axis)

# Not cool.
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# To invert the y-axis to have the months in ascending order, use the gca() method. The gca() method means "get current axes." We can chain the gca() method to the invert_yaxis() method by using gca().invert_yaxis(), as shown here:

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %% [markdown]
# ### SKILL DRILL

# %%
# Change the bar colors to magenta.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")

# Add a legend for the city of Boston.
plt.legend()

# Add a title and axes labels.
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")

# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %% [markdown]
# # 5.1.6 Create Bar Charts Using the Object-Oriented Approach

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# ## Create a Vertical Bar Chart

# %% [markdown]
# ### Object-Oriented Graph Types
# ax.plot = line chart
#
# ax.bar = vertical bar chart
#
# ax.barh = horizontal bar chart
#
# ax.invert_yaxis() = invert the order of the y axis (handy when showing most recent month to month logest ago)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

ax.bar(x_axis, y_axis, color="black", label='New York')

# Where is the New York label??
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ## Create a Horizontal Bar Chart

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt() to make it look dumb and be useless.
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="Chicago")
ax.legend()
ax.set_title("PyBer Fare By Month")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
ax.invert_yaxis()

# %% [markdown]
# # 5.1.7 Create Scatter Plots and Bubble Charts

# %% [markdown]
# Shortcuts
#
# "c=" is short for color=
#
# "s=" is short for size=
#
#     If you set size to X, the size of the X will be dependent on the value of X (or Y)

# %% [markdown]
# Scatter plots are particularly good at depicting multiple datasets on the same chart.
# Scatter plots have many benefits over line and bar charts. A scatter plot visually depicts a positive, negative, or no-correlation relationship between two factors.
#
# Scatter plots are often used for regression analysis. When r value is positive and close to zero, there is no correlation.

# %% [markdown]
# ## Create a Scatter Plot Using the MATLAB Method

# %% [markdown]
# ### plt.plot()

# %%
# Add an "o" at the end so it's not a line chart.
plt.plot(x_axis, y_axis, 'o')

# %% [markdown]
# ### plt.scatter()

# %%
plt.scatter(x_axis, y_axis)

# %% [markdown]
# ### SKILL DRILL

# %%
# Change the color of the markers to red. Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(x_axis, y_axis, c="red", label='Chicago')

# Add a legend for the city of Chicago.
plt.legend()

# Add a title and axes labels.
plt.title("PyBer Fare by Month")
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Add a limit for the x-axis data.
plt.ylim(0, 45)

# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %% [markdown]
# ## Create a Bubble Chart Using the MATLAB Method

# %% [markdown]
# Bubble charts are useful when presenting financial, population, and weather data because you can add a third and fourth factor to convey more information.: x axis, y axis, size and color.

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %% [markdown]
# To make the dots bigger for more impact, multiply the y-axis by any number.

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %% [markdown]
# We can refactor the code we used to create a scatter plot above, but instead of using a for loop to create the list y_axis_larger for the size parameter of the marker, we can use Python's list comprehension technique inside the plt.scatter() function. You can use list comprehension to replace many for and while loops. List comprehension is faster because it is optimized for Python to spot a predictable pattern during looping.
#
# new_list = [expression for item in list if conditional]

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %% [markdown]
# ## Create a Scatter Plot Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %% [markdown]
# ## Create a Bubble Chart Using the Object-Oriented Interface

# %% [markdown]
# To get bubbles, it's same as MATLAB.

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()

# Change the color of the markers to sky blue.
# Change the size of the markers to 5 times each data point.
# Make the color 20% transparent.
# Make the linewidth of the circles 2 points.
# Add a black edge color to the circles.
ax.scatter(x_axis, y_axis, linewidth=2, c="xkcd:sky blue", alpha=0.2, edgecolor="k", label='Boston', s = [i * 5 for i in y_axis])
# HOW DO I CHANGE THE EDGE COLOR OFF OF 20% TRANSPARENT??

# Add a legend for the city of Boston.
ax.legend()

# Add a title.
ax.set_title("PyBer Fare by Month")

# Switch the axis so that the Fare($) data is on the x-axis.
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")

# Add a limit for the x-axis data.
ax.set_ylim(0, 50)

# Invert the y-axis so that January is at the top.
ax.invert_yaxis()

# %% [markdown]
# # 5.1.8 Create Pie Charts

# %% [markdown]
# ## Create a Pie Chart Using the MATLAB Method

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %% [markdown]
# The "explode" parameter will offset the indicated wedge by a fraction of the radius, where "0" is zero distance from the center of the pie, and "1" is completely outside the diameter of the pie.

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.show()

# %% [markdown]
# Let's break down what the graphing code is doing:
#
# * To explode a pie wedge, we use array-like data points (like the tuple explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)) for each value in the pie chart.
#     * The length of the tuple should be equal to the number of wedges in the pie chart.
#     * The value specified to "explode" a wedge is the fraction of the radius from the center of the pie for each wedge.
# * To pop out the seventh month, July, we use a decimal-point value of 0.2.
# * To add the percentage of each wedge on the pie chart, we use the autopct parameter and provide the format of one decimal place using .1f%.
# * The % before and after the .1f% formats the number as a percentage.
# * The graph was crowded so we increased it to 8, 8. (This must be added on the first line of code to work correctly.)

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %% [markdown]
# ## Create a Pie Chart Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
ax.pie
# Out:
# <bound method Axes.pie of <AxesSubplot:>>

# %% [markdown]
# ### SKILL DRILL

# %%
# Increase the figure size to 8x8.
fig, ax = plt.subplots(figsize=[8,8])

# Explode the two highest percentage months.
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

# Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

# Add a percentage to one decimal place to each wedge of the pie.
# Add a shadow.
# Add a start angle so that January is at the top.
ax.pie(y_axis, explode=explode_values, labels=x_axis, colors=colors, autopct='%.1f%%', shadow=True, startangle=270)

# Reverse the order so that the month order is in a clockwise direction.
ax.invert_yaxis()

# %% [markdown]
# See matplotlip_practice_ChartExtras for more http://localhost:8888/notebooks/matplotlib_practice_ChartExtras.ipynb#
